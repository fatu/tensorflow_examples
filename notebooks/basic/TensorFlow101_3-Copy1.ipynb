# %% [markdown]
# # TensorFlow 101
#
# ### 1. Basic syntax
# ### 2. TensorFlow Graphs
# ### 3. tf.Variable
# ### 4. tf.Placeholder
# ### 5. TensorFlow Neural Network
# ### 6. TensorFlow Regression and Classification
# ### 7. Estimator API
# ### 8. Save and Restore Model

# %% [markdown]
# ## Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x10c839080>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 235.753
# INFO:tensorflow:loss = 5.516858, step = 101 (0.427 sec)
# INFO:tensorflow:global_step/sec: 371.121
# INFO:tensorflow:loss = 5.7591786, step = 201 (0.268 sec)
# INFO:tensorflow:global_step/sec: 525.851
# INFO:tensorflow:loss = 7.764969, step = 301 (0.190 sec)
# INFO:tensorflow:global_step/sec: 503.644
# INFO:tensorflow:loss = 8.097218, step = 401 (0.199 sec)
# INFO:tensorflow:global_step/sec: 484.663
# INFO:tensorflow:loss = 6.627715, step = 501 (0.206 sec)
# INFO:tensorflow:global_step/sec: 458.802
# INFO:tensorflow:loss = 4.4405675, step = 601 (0.219 sec)
# INFO:tensorflow:global_step/sec: 416.384
# INFO:tensorflow:loss = 8.917076, step = 701 (0.238 sec)
# INFO:tensorflow:global_step/sec: 515.772
# INFO:tensorflow:loss = 3.3906384, step = 801 (0.193 sec)
# INFO:tensorflow:global_step/sec: 541.841
# INFO:tensorflow:loss = 5.39686, step = 901 (0.184 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.0069256.

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-10-22:21:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-10-22:21:16
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.70866144, accuracy_baseline = 0.65748036, auc = 0.7895244, auc_precision_recall = 0.6274702, average_loss = 0.5378405, global_step = 1000, label/mean = 0.34251967, loss = 5.2542877, precision = 0.5730337, prediction/mean = 0.40104768, recall = 0.5862069

# %%
results
# Out:
# {'accuracy': 0.70866144,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7895244,
#  'auc_precision_recall': 0.6274702,
#  'average_loss': 0.5378405,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2542877,
#  'precision': 0.5730337,
#  'prediction/mean': 0.40104768,
#  'recall': 0.5862069}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmptnz4_qx6/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56615317], dtype=float32),
#   'logits': array([0.26617312], dtype=float32),
#   'probabilities': array([0.43384683, 0.56615317], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.672615], dtype=float32),
#   'logits': array([0.72003627], dtype=float32),
#   'probabilities': array([0.32738498, 0.672615  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40293112], dtype=float32),
#   'logits': array([-0.39326674], dtype=float32),
#   'probabilities': array([0.59706885, 0.40293115], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36809897], dtype=float32),
#   'logits': array([-0.54038095], dtype=float32),
#   'probabilities': array([0.631901  , 0.36809897], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17290084], dtype=float32),
#   'logits': array([-1.5652063], dtype=float32),
#   'probabilities': array([0.82709914, 0.17290086], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7399639], dtype=float32),
#   'logits': array([1.0457809], dtype=float32),
#   'probabilities': array([0.2600361, 0.7399639], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.635608], dtype=float32),
#   'logits': array([0.5563519], dtype=float32),
#   'probabilities': array([0.36439195, 0.635608  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37510312], dtype=float32),
#   'logits': array([-0.51038575], dtype=float32),
#   'probabilities': array([0.6248969, 0.3751031], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26885635], dtype=float32),
#   'logits': array([-1.0004327], dtype=float32),
#   'probabilities': array([0.73114365, 0.26885635], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27895123], dtype=float32),
#   'logits': array([-0.94966984], dtype=float32),
#   'probabilities': array([0.7210488 , 0.27895123], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15243268], dtype=float32),
#   'logits': array([-1.7156472], dtype=float32),
#   'probabilities': array([0.8475674, 0.1524327], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18100956], dtype=float32),
#   'logits': array([-1.5095226], dtype=float32),
#   'probabilities': array([0.81899047, 0.18100956], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32519472], dtype=float32),
#   'logits': array([-0.73], dtype=float32),
#   'probabilities': array([0.6748052, 0.3251947], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61117285], dtype=float32),
#   'logits': array([0.45224476], dtype=float32),
#   'probabilities': array([0.3888272 , 0.61117285], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20452136], dtype=float32),
#   'logits': array([-1.3582716], dtype=float32),
#   'probabilities': array([0.79547864, 0.20452136], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3529995], dtype=float32),
#   'logits': array([-0.6058805], dtype=float32),
#   'probabilities': array([0.64700055, 0.35299948], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40091383], dtype=float32),
#   'logits': array([-0.40165895], dtype=float32),
#   'probabilities': array([0.59908617, 0.40091383], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15578407], dtype=float32),
#   'logits': array([-1.6899374], dtype=float32),
#   'probabilities': array([0.8442159 , 0.15578409], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39318395], dtype=float32),
#   'logits': array([-0.43394804], dtype=float32),
#   'probabilities': array([0.60681605, 0.393184  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16211721], dtype=float32),
#   'logits': array([-1.6425586], dtype=float32),
#   'probabilities': array([0.8378828 , 0.16211723], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24254902], dtype=float32),
#   'logits': array([-1.1387551], dtype=float32),
#   'probabilities': array([0.757451  , 0.24254902], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3348665], dtype=float32),
#   'logits': array([-0.6862558], dtype=float32),
#   'probabilities': array([0.66513354, 0.33486652], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68681484], dtype=float32),
#   'logits': array([0.7852702], dtype=float32),
#   'probabilities': array([0.31318513, 0.68681484], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25193152], dtype=float32),
#   'logits': array([-1.0883372], dtype=float32),
#   'probabilities': array([0.74806845, 0.25193152], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19330955], dtype=float32),
#   'logits': array([-1.4286473], dtype=float32),
#   'probabilities': array([0.80669045, 0.19330955], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7918163], dtype=float32),
#   'logits': array([1.3359084], dtype=float32),
#   'probabilities': array([0.20818372, 0.7918163 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20481569], dtype=float32),
#   'logits': array([-1.3564634], dtype=float32),
#   'probabilities': array([0.7951844 , 0.20481572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35671496], dtype=float32),
#   'logits': array([-0.5896509], dtype=float32),
#   'probabilities': array([0.64328504, 0.35671496], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.120442], dtype=float32),
#   'logits': array([-1.9882512], dtype=float32),
#   'probabilities': array([0.879558, 0.120442], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6188951], dtype=float32),
#   'logits': array([0.48486102], dtype=float32),
#   'probabilities': array([0.38110498, 0.6188951 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.954282], dtype=float32),
#   'logits': array([3.0384667], dtype=float32),
#   'probabilities': array([0.04571802, 0.954282  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45772406], dtype=float32),
#   'logits': array([-0.16950846], dtype=float32),
#   'probabilities': array([0.54227597, 0.4577241 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3541027], dtype=float32),
#   'logits': array([-0.6010536], dtype=float32),
#   'probabilities': array([0.6458973, 0.3541027], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61695004], dtype=float32),
#   'logits': array([0.4766227], dtype=float32),
#   'probabilities': array([0.3830499 , 0.61695004], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2650209], dtype=float32),
#   'logits': array([-1.0200334], dtype=float32),
#   'probabilities': array([0.7349791, 0.2650209], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39759782], dtype=float32),
#   'logits': array([-0.41548425], dtype=float32),
#   'probabilities': array([0.60240215, 0.39759782], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54408294], dtype=float32),
#   'logits': array([0.17679095], dtype=float32),
#   'probabilities': array([0.455917  , 0.54408294], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6784028], dtype=float32),
#   'logits': array([0.74644136], dtype=float32),
#   'probabilities': array([0.3215972, 0.6784028], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7867115], dtype=float32),
#   'logits': array([1.3052158], dtype=float32),
#   'probabilities': array([0.21328852, 0.7867115 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.370541], dtype=float32),
#   'logits': array([-0.5298966], dtype=float32),
#   'probabilities': array([0.62945896, 0.370541  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2072736], dtype=float32),
#   'logits': array([-1.3414384], dtype=float32),
#   'probabilities': array([0.79272634, 0.2072736 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5993177], dtype=float32),
#   'logits': array([0.40262318], dtype=float32),
#   'probabilities': array([0.40068224, 0.5993177 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.164871], dtype=float32),
#   'logits': array([-1.6224228], dtype=float32),
#   'probabilities': array([0.835129, 0.164871], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.563329], dtype=float32),
#   'logits': array([0.25468373], dtype=float32),
#   'probabilities': array([0.43667102, 0.563329  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15298255], dtype=float32),
#   'logits': array([-1.7113974], dtype=float32),
#   'probabilities': array([0.8470174 , 0.15298255], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12090409], dtype=float32),
#   'logits': array([-1.9838964], dtype=float32),
#   'probabilities': array([0.87909585, 0.12090408], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65977], dtype=float32),
#   'logits': array([0.66226935], dtype=float32),
#   'probabilities': array([0.34023002, 0.65977   ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22151157], dtype=float32),
#   'logits': array([-1.2568793], dtype=float32),
#   'probabilities': array([0.7784884 , 0.22151156], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22153783], dtype=float32),
#   'logits': array([-1.256727], dtype=float32),
#   'probabilities': array([0.7784622 , 0.22153784], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13324805], dtype=float32),
#   'logits': array([-1.8725405], dtype=float32),
#   'probabilities': array([0.8667519 , 0.13324803], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1939304], dtype=float32),
#   'logits': array([-1.4246707], dtype=float32),
#   'probabilities': array([0.80606955, 0.1939304 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29014522], dtype=float32),
#   'logits': array([-0.8946788], dtype=float32),
#   'probabilities': array([0.7098548 , 0.29014525], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2882395], dtype=float32),
#   'logits': array([-0.9039497], dtype=float32),
#   'probabilities': array([0.71176046, 0.2882395 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41541713], dtype=float32),
#   'logits': array([-0.34161526], dtype=float32),
#   'probabilities': array([0.5845828 , 0.41541716], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14386389], dtype=float32),
#   'logits': array([-1.7835617], dtype=float32),
#   'probabilities': array([0.8561361 , 0.14386389], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25074732], dtype=float32),
#   'logits': array([-1.0946306], dtype=float32),
#   'probabilities': array([0.74925274, 0.25074732], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24583937], dtype=float32),
#   'logits': array([-1.120927], dtype=float32),
#   'probabilities': array([0.75416064, 0.24583939], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23687142], dtype=float32),
#   'logits': array([-1.1699091], dtype=float32),
#   'probabilities': array([0.7631286, 0.2368714], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51598877], dtype=float32),
#   'logits': array([0.06397688], dtype=float32),
#   'probabilities': array([0.48401123, 0.51598877], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18925379], dtype=float32),
#   'logits': array([-1.454866], dtype=float32),
#   'probabilities': array([0.81074625, 0.1892538 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26642004], dtype=float32),
#   'logits': array([-1.0128624], dtype=float32),
#   'probabilities': array([0.73358   , 0.26642004], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68130684], dtype=float32),
#   'logits': array([0.75978386], dtype=float32),
#   'probabilities': array([0.3186932 , 0.68130684], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67645705], dtype=float32),
#   'logits': array([0.73753715], dtype=float32),
#   'probabilities': array([0.32354295, 0.67645705], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5541411], dtype=float32),
#   'logits': array([0.21741688], dtype=float32),
#   'probabilities': array([0.44585887, 0.5541411 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39726856], dtype=float32),
#   'logits': array([-0.41685915], dtype=float32),
#   'probabilities': array([0.6027314 , 0.39726856], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51197326], dtype=float32),
#   'logits': array([0.04790211], dtype=float32),
#   'probabilities': array([0.4880268 , 0.51197326], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20811039], dtype=float32),
#   'logits': array([-1.3363533], dtype=float32),
#   'probabilities': array([0.7918896 , 0.20811039], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21414973], dtype=float32),
#   'logits': array([-1.3000908], dtype=float32),
#   'probabilities': array([0.7858502 , 0.21414971], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17580272], dtype=float32),
#   'logits': array([-1.5450475], dtype=float32),
#   'probabilities': array([0.82419723, 0.1758027 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14371839], dtype=float32),
#   'logits': array([-1.7847435], dtype=float32),
#   'probabilities': array([0.8562816 , 0.14371838], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6508225], dtype=float32),
#   'logits': array([0.6226568], dtype=float32),
#   'probabilities': array([0.34917745, 0.6508225 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25101942], dtype=float32),
#   'logits': array([-1.0931828], dtype=float32),
#   'probabilities': array([0.7489806 , 0.25101942], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4735457], dtype=float32),
#   'logits': array([-0.10591602], dtype=float32),
#   'probabilities': array([0.52645427, 0.47354573], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6232227], dtype=float32),
#   'logits': array([0.50324965], dtype=float32),
#   'probabilities': array([0.37677732, 0.6232227 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32517266], dtype=float32),
#   'logits': array([-0.7301005], dtype=float32),
#   'probabilities': array([0.67482734, 0.32517266], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6822859], dtype=float32),
#   'logits': array([0.764297], dtype=float32),
#   'probabilities': array([0.31771407, 0.6822859 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1499793], dtype=float32),
#   'logits': array([-1.7347635], dtype=float32),
#   'probabilities': array([0.8500207, 0.1499793], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63708293], dtype=float32),
#   'logits': array([0.56272554], dtype=float32),
#   'probabilities': array([0.36291707, 0.63708293], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14670835], dtype=float32),
#   'logits': array([-1.7606547], dtype=float32),
#   'probabilities': array([0.8532917 , 0.14670837], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60466963], dtype=float32),
#   'logits': array([0.4249605], dtype=float32),
#   'probabilities': array([0.39533034, 0.60466963], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3624764], dtype=float32),
#   'logits': array([-0.5646319], dtype=float32),
#   'probabilities': array([0.6375236, 0.3624764], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17800587], dtype=float32),
#   'logits': array([-1.5299166], dtype=float32),
#   'probabilities': array([0.8219941 , 0.17800589], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60430086], dtype=float32),
#   'logits': array([0.42341793], dtype=float32),
#   'probabilities': array([0.3956992 , 0.60430086], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63866436], dtype=float32),
#   'logits': array([0.56957185], dtype=float32),
#   'probabilities': array([0.36133564, 0.63866436], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5794892], dtype=float32),
#   'logits': array([0.32067692], dtype=float32),
#   'probabilities': array([0.42051074, 0.5794892 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19114691], dtype=float32),
#   'logits': array([-1.4425751], dtype=float32),
#   'probabilities': array([0.8088531, 0.1911469], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36776942], dtype=float32),
#   'logits': array([-0.541798], dtype=float32),
#   'probabilities': array([0.6322306 , 0.36776942], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1826934], dtype=float32),
#   'logits': array([-1.498205], dtype=float32),
#   'probabilities': array([0.81730664, 0.1826934 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7256506], dtype=float32),
#   'logits': array([0.972666], dtype=float32),
#   'probabilities': array([0.27434945, 0.7256506 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8340153], dtype=float32),
#   'logits': array([1.6143565], dtype=float32),
#   'probabilities': array([0.16598463, 0.8340153 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6583206], dtype=float32),
#   'logits': array([0.6558192], dtype=float32),
#   'probabilities': array([0.34167942, 0.6583206 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24891631], dtype=float32),
#   'logits': array([-1.1044004], dtype=float32),
#   'probabilities': array([0.7510837, 0.2489163], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49344438], dtype=float32),
#   'logits': array([-0.02622378], dtype=float32),
#   'probabilities': array([0.50655556, 0.49344444], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4213294], dtype=float32),
#   'logits': array([-0.31731832], dtype=float32),
#   'probabilities': array([0.57867056, 0.42132944], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47475073], dtype=float32),
#   'logits': array([-0.10108304], dtype=float32),
#   'probabilities': array([0.52524924, 0.4747507 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38559875], dtype=float32),
#   'logits': array([-0.46585095], dtype=float32),
#   'probabilities': array([0.6144013 , 0.38559872], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4784478], dtype=float32),
#   'logits': array([-0.08626235], dtype=float32),
#   'probabilities': array([0.5215522 , 0.47844774], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16983874], dtype=float32),
#   'logits': array([-1.5867705], dtype=float32),
#   'probabilities': array([0.8301612 , 0.16983874], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6069156], dtype=float32),
#   'logits': array([0.43436527], dtype=float32),
#   'probabilities': array([0.39308444, 0.6069156 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61579925], dtype=float32),
#   'logits': array([0.47175562], dtype=float32),
#   'probabilities': array([0.3842008 , 0.61579925], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27552482], dtype=float32),
#   'logits': array([-0.9667697], dtype=float32),
#   'probabilities': array([0.72447515, 0.27552482], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19268042], dtype=float32),
#   'logits': array([-1.4326867], dtype=float32),
#   'probabilities': array([0.80731964, 0.19268042], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19909889], dtype=float32),
#   'logits': array([-1.3919358], dtype=float32),
#   'probabilities': array([0.8009011 , 0.19909889], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31944624], dtype=float32),
#   'logits': array([-0.75631785], dtype=float32),
#   'probabilities': array([0.6805538 , 0.31944624], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41982412], dtype=float32),
#   'logits': array([-0.3234954], dtype=float32),
#   'probabilities': array([0.5801759 , 0.41982412], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14744075], dtype=float32),
#   'logits': array([-1.7548163], dtype=float32),
#   'probabilities': array([0.8525592 , 0.14744075], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37162206], dtype=float32),
#   'logits': array([-0.52526444], dtype=float32),
#   'probabilities': array([0.6283779 , 0.37162206], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26814353], dtype=float32),
#   'logits': array([-1.0040619], dtype=float32),
#   'probabilities': array([0.73185647, 0.26814356], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11713919], dtype=float32),
#   'logits': array([-2.0198047], dtype=float32),
#   'probabilities': array([0.88286084, 0.11713918], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14504604], dtype=float32),
#   'logits': array([-1.7739964], dtype=float32),
#   'probabilities': array([0.85495394, 0.14504606], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78716487], dtype=float32),
#   'logits': array([1.30792], dtype=float32),
#   'probabilities': array([0.2128351 , 0.78716487], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20179947], dtype=float32),
#   'logits': array([-1.3750854], dtype=float32),
#   'probabilities': array([0.79820055, 0.20179948], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14374559], dtype=float32),
#   'logits': array([-1.7845225], dtype=float32),
#   'probabilities': array([0.8562544 , 0.14374559], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16672802], dtype=float32),
#   'logits': array([-1.6089963], dtype=float32),
#   'probabilities': array([0.833272  , 0.16672802], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5220186], dtype=float32),
#   'logits': array([0.08813143], dtype=float32),
#   'probabilities': array([0.4779814, 0.5220186], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5115159], dtype=float32),
#   'logits': array([0.04607177], dtype=float32),
#   'probabilities': array([0.48848408, 0.5115159 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26697093], dtype=float32),
#   'logits': array([-1.0100456], dtype=float32),
#   'probabilities': array([0.73302907, 0.2669709 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48173127], dtype=float32),
#   'logits': array([-0.07310748], dtype=float32),
#   'probabilities': array([0.5182687 , 0.48173124], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19760129], dtype=float32),
#   'logits': array([-1.4013543], dtype=float32),
#   'probabilities': array([0.8023987 , 0.19760129], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2620901], dtype=float32),
#   'logits': array([-1.0351335], dtype=float32),
#   'probabilities': array([0.7379099, 0.2620901], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55004996], dtype=float32),
#   'logits': array([0.20087242], dtype=float32),
#   'probabilities': array([0.4499501 , 0.55004996], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5095131], dtype=float32),
#   'logits': array([0.03805685], dtype=float32),
#   'probabilities': array([0.49048695, 0.5095131 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15160865], dtype=float32),
#   'logits': array([-1.7220396], dtype=float32),
#   'probabilities': array([0.84839135, 0.15160863], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4567263], dtype=float32),
#   'logits': array([-0.17352897], dtype=float32),
#   'probabilities': array([0.54327375, 0.4567263 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7244171], dtype=float32),
#   'logits': array([0.9664788], dtype=float32),
#   'probabilities': array([0.2755829, 0.7244171], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56760687], dtype=float32),
#   'logits': array([0.2720939], dtype=float32),
#   'probabilities': array([0.43239313, 0.56760687], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41898096], dtype=float32),
#   'logits': array([-0.32695806], dtype=float32),
#   'probabilities': array([0.58101904, 0.41898096], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58549064], dtype=float32),
#   'logits': array([0.3453548], dtype=float32),
#   'probabilities': array([0.4145093 , 0.58549064], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2620181], dtype=float32),
#   'logits': array([-1.0355057], dtype=float32),
#   'probabilities': array([0.7379819, 0.2620181], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21031228], dtype=float32),
#   'logits': array([-1.3230442], dtype=float32),
#   'probabilities': array([0.78968775, 0.21031228], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14318481], dtype=float32),
#   'logits': array([-1.7890861], dtype=float32),
#   'probabilities': array([0.8568152 , 0.14318481], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30484164], dtype=float32),
#   'logits': array([-0.8243472], dtype=float32),
#   'probabilities': array([0.69515836, 0.30484167], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5305648], dtype=float32),
#   'logits': array([0.12241185], dtype=float32),
#   'probabilities': array([0.46943516, 0.5305648 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71513844], dtype=float32),
#   'logits': array([0.92047286], dtype=float32),
#   'probabilities': array([0.28486153, 0.71513844], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2641847], dtype=float32),
#   'logits': array([-1.0243306], dtype=float32),
#   'probabilities': array([0.7358153, 0.2641847], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18811569], dtype=float32),
#   'logits': array([-1.4623008], dtype=float32),
#   'probabilities': array([0.81188434, 0.18811569], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4655184], dtype=float32),
#   'logits': array([-0.13814557], dtype=float32),
#   'probabilities': array([0.5344816 , 0.46551844], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25887868], dtype=float32),
#   'logits': array([-1.0518048], dtype=float32),
#   'probabilities': array([0.7411213 , 0.25887868], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16337514], dtype=float32),
#   'logits': array([-1.6333268], dtype=float32),
#   'probabilities': array([0.83662486, 0.16337512], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21264252], dtype=float32),
#   'logits': array([-1.30907], dtype=float32),
#   'probabilities': array([0.78735745, 0.2126425 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14559111], dtype=float32),
#   'logits': array([-1.7696078], dtype=float32),
#   'probabilities': array([0.8544089 , 0.14559112], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4332777], dtype=float32),
#   'logits': array([-0.26849055], dtype=float32),
#   'probabilities': array([0.56672233, 0.43327773], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8138298], dtype=float32),
#   'logits': array([1.4750898], dtype=float32),
#   'probabilities': array([0.18617022, 0.8138298 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80254185], dtype=float32),
#   'logits': array([1.4022574], dtype=float32),
#   'probabilities': array([0.19745813, 0.80254185], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57440245], dtype=float32),
#   'logits': array([0.29983604], dtype=float32),
#   'probabilities': array([0.42559758, 0.57440245], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5473803], dtype=float32),
#   'logits': array([0.19009173], dtype=float32),
#   'probabilities': array([0.45261967, 0.5473803 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61314356], dtype=float32),
#   'logits': array([0.46054554], dtype=float32),
#   'probabilities': array([0.3868564 , 0.61314356], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12818043], dtype=float32),
#   'logits': array([-1.9171436], dtype=float32),
#   'probabilities': array([0.8718196 , 0.12818044], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5831709], dtype=float32),
#   'logits': array([0.3358041], dtype=float32),
#   'probabilities': array([0.41682905, 0.5831709 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8006556], dtype=float32),
#   'logits': array([1.3903971], dtype=float32),
#   'probabilities': array([0.19934437, 0.8006556 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46042538], dtype=float32),
#   'logits': array([-0.15863031], dtype=float32),
#   'probabilities': array([0.5395746 , 0.46042538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29414025], dtype=float32),
#   'logits': array([-0.8753599], dtype=float32),
#   'probabilities': array([0.7058597 , 0.29414022], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3827249], dtype=float32),
#   'logits': array([-0.47799832], dtype=float32),
#   'probabilities': array([0.6172751, 0.3827249], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64020866], dtype=float32),
#   'logits': array([0.57626987], dtype=float32),
#   'probabilities': array([0.35979134, 0.64020866], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26952916], dtype=float32),
#   'logits': array([-0.9970128], dtype=float32),
#   'probabilities': array([0.73047084, 0.26952913], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6815805], dtype=float32),
#   'logits': array([0.7610446], dtype=float32),
#   'probabilities': array([0.3184195, 0.6815805], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45346856], dtype=float32),
#   'logits': array([-0.18666583], dtype=float32),
#   'probabilities': array([0.54653144, 0.4534686 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46874762], dtype=float32),
#   'logits': array([-0.12517273], dtype=float32),
#   'probabilities': array([0.5312524 , 0.46874762], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18402214], dtype=float32),
#   'logits': array([-1.4893311], dtype=float32),
#   'probabilities': array([0.8159779 , 0.18402214], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20044215], dtype=float32),
#   'logits': array([-1.3835332], dtype=float32),
#   'probabilities': array([0.79955786, 0.20044215], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21753457], dtype=float32),
#   'logits': array([-1.280092], dtype=float32),
#   'probabilities': array([0.78246546, 0.21753456], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46540362], dtype=float32),
#   'logits': array([-0.1386069], dtype=float32),
#   'probabilities': array([0.5345964 , 0.46540368], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16711588], dtype=float32),
#   'logits': array([-1.606207], dtype=float32),
#   'probabilities': array([0.83288413, 0.1671159 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7408346], dtype=float32),
#   'logits': array([1.0503109], dtype=float32),
#   'probabilities': array([0.2591654, 0.7408346], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23088907], dtype=float32),
#   'logits': array([-1.2032979], dtype=float32),
#   'probabilities': array([0.7691109 , 0.23088905], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55039203], dtype=float32),
#   'logits': array([0.20225477], dtype=float32),
#   'probabilities': array([0.44960797, 0.55039203], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17254929], dtype=float32),
#   'logits': array([-1.5676666], dtype=float32),
#   'probabilities': array([0.82745075, 0.17254929], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7137127], dtype=float32),
#   'logits': array([0.9134846], dtype=float32),
#   'probabilities': array([0.2862873, 0.7137127], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34417543], dtype=float32),
#   'logits': array([-0.64474183], dtype=float32),
#   'probabilities': array([0.65582454, 0.34417543], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22788541], dtype=float32),
#   'logits': array([-1.22029], dtype=float32),
#   'probabilities': array([0.7721146 , 0.22788544], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37272587], dtype=float32),
#   'logits': array([-0.5205404], dtype=float32),
#   'probabilities': array([0.6272741 , 0.37272587], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37630922], dtype=float32),
#   'logits': array([-0.5052435], dtype=float32),
#   'probabilities': array([0.6236908 , 0.37630922], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19159497], dtype=float32),
#   'logits': array([-1.4396796], dtype=float32),
#   'probabilities': array([0.80840504, 0.19159497], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75687337], dtype=float32),
#   'logits': array([1.1356139], dtype=float32),
#   'probabilities': array([0.24312654, 0.75687337], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.225305], dtype=float32),
#   'logits': array([-1.2350143], dtype=float32),
#   'probabilities': array([0.774695  , 0.22530502], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19464181], dtype=float32),
#   'logits': array([-1.4201262], dtype=float32),
#   'probabilities': array([0.80535823, 0.19464181], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30718726], dtype=float32),
#   'logits': array([-0.8133023], dtype=float32),
#   'probabilities': array([0.69281274, 0.30718723], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45763874], dtype=float32),
#   'logits': array([-0.16985226], dtype=float32),
#   'probabilities': array([0.54236126, 0.4576387 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29018018], dtype=float32),
#   'logits': array([-0.8945092], dtype=float32),
#   'probabilities': array([0.7098198 , 0.29018015], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1399106], dtype=float32),
#   'logits': array([-1.8160328], dtype=float32),
#   'probabilities': array([0.8600894, 0.1399106], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8619415], dtype=float32),
#   'logits': array([1.8315101], dtype=float32),
#   'probabilities': array([0.13805847, 0.8619415 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7001606], dtype=float32),
#   'logits': array([0.84806263], dtype=float32),
#   'probabilities': array([0.29983944, 0.7001606 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54351616], dtype=float32),
#   'logits': array([0.17450607], dtype=float32),
#   'probabilities': array([0.45648387, 0.54351616], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7697643], dtype=float32),
#   'logits': array([1.2069807], dtype=float32),
#   'probabilities': array([0.23023573, 0.7697643 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12971109], dtype=float32),
#   'logits': array([-1.9035156], dtype=float32),
#   'probabilities': array([0.8702889, 0.1297111], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16631116], dtype=float32),
#   'logits': array([-1.6119998], dtype=float32),
#   'probabilities': array([0.83368886, 0.16631116], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24493854], dtype=float32),
#   'logits': array([-1.1257918], dtype=float32),
#   'probabilities': array([0.75506145, 0.24493854], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38176864], dtype=float32),
#   'logits': array([-0.48204792], dtype=float32),
#   'probabilities': array([0.61823136, 0.38176867], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4092114], dtype=float32),
#   'logits': array([-0.3672263], dtype=float32),
#   'probabilities': array([0.59078854, 0.4092114 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61341137], dtype=float32),
#   'logits': array([0.4616747], dtype=float32),
#   'probabilities': array([0.3865886 , 0.61341137], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.600332], dtype=float32),
#   'logits': array([0.40684867], dtype=float32),
#   'probabilities': array([0.39966798, 0.600332  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43458408], dtype=float32),
#   'logits': array([-0.2631722], dtype=float32),
#   'probabilities': array([0.5654159 , 0.43458405], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38289326], dtype=float32),
#   'logits': array([-0.47728574], dtype=float32),
#   'probabilities': array([0.61710674, 0.38289326], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39162067], dtype=float32),
#   'logits': array([-0.4405049], dtype=float32),
#   'probabilities': array([0.6083793 , 0.39162064], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21713474], dtype=float32),
#   'logits': array([-1.2824425], dtype=float32),
#   'probabilities': array([0.7828653 , 0.21713476], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6751197], dtype=float32),
#   'logits': array([0.73143315], dtype=float32),
#   'probabilities': array([0.32488033, 0.6751197 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15072288], dtype=float32),
#   'logits': array([-1.7289426], dtype=float32),
#   'probabilities': array([0.8492771 , 0.15072288], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28069028], dtype=float32),
#   'logits': array([-0.9410401], dtype=float32),
#   'probabilities': array([0.71930975, 0.2806903 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58712435], dtype=float32),
#   'logits': array([0.35209012], dtype=float32),
#   'probabilities': array([0.41287565, 0.58712435], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38286182], dtype=float32),
#   'logits': array([-0.47741878], dtype=float32),
#   'probabilities': array([0.61713815, 0.38286182], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22208767], dtype=float32),
#   'logits': array([-1.2535417], dtype=float32),
#   'probabilities': array([0.7779123 , 0.22208765], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29229096], dtype=float32),
#   'logits': array([-0.8842834], dtype=float32),
#   'probabilities': array([0.7077091 , 0.29229096], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2921299], dtype=float32),
#   'logits': array([-0.88506204], dtype=float32),
#   'probabilities': array([0.7078701, 0.2921299], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1611218], dtype=float32),
#   'logits': array([-1.649905], dtype=float32),
#   'probabilities': array([0.8388783, 0.1611218], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21728665], dtype=float32),
#   'logits': array([-1.2815491], dtype=float32),
#   'probabilities': array([0.78271335, 0.21728666], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6282063], dtype=float32),
#   'logits': array([0.5245296], dtype=float32),
#   'probabilities': array([0.3717937, 0.6282063], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.71784395], dtype=float32),
#   'logits': array([0.9337919], dtype=float32),
#   'probabilities': array([0.28215605, 0.71784395], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6735024], dtype=float32),
#   'logits': array([0.72406876], dtype=float32),
#   'probabilities': array([0.32649767, 0.6735024 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72536033], dtype=float32),
#   'logits': array([0.9712086], dtype=float32),
#   'probabilities': array([0.27463967, 0.72536033], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51073754], dtype=float32),
#   'logits': array([0.04295683], dtype=float32),
#   'probabilities': array([0.48926243, 0.51073754], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33845565], dtype=float32),
#   'logits': array([-0.670184], dtype=float32),
#   'probabilities': array([0.6615444 , 0.33845565], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56107503], dtype=float32),
#   'logits': array([0.24552608], dtype=float32),
#   'probabilities': array([0.43892503, 0.56107503], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20261376], dtype=float32),
#   'logits': array([-1.3700378], dtype=float32),
#   'probabilities': array([0.7973863 , 0.20261374], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1712811], dtype=float32),
#   'logits': array([-1.576575], dtype=float32),
#   'probabilities': array([0.82871896, 0.17128108], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20686257], dtype=float32),
#   'logits': array([-1.3439418], dtype=float32),
#   'probabilities': array([0.7931374 , 0.20686257], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.543166], dtype=float32),
#   'logits': array([0.17309475], dtype=float32),
#   'probabilities': array([0.45683405, 0.543166  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06950584], dtype=float32),
#   'logits': array([-2.594305], dtype=float32),
#   'probabilities': array([0.9304942 , 0.06950584], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31451005], dtype=float32),
#   'logits': array([-0.7791178], dtype=float32),
#   'probabilities': array([0.68548995, 0.31451005], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19141892], dtype=float32),
#   'logits': array([-1.4408166], dtype=float32),
#   'probabilities': array([0.80858105, 0.1914189 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30695716], dtype=float32),
#   'logits': array([-0.8143836], dtype=float32),
#   'probabilities': array([0.6930429, 0.3069572], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26545385], dtype=float32),
#   'logits': array([-1.0178119], dtype=float32),
#   'probabilities': array([0.7345461 , 0.26545382], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31682798], dtype=float32),
#   'logits': array([-0.76838773], dtype=float32),
#   'probabilities': array([0.68317205, 0.31682798], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.80448955], dtype=float32),
#   'logits': array([1.4145939], dtype=float32),
#   'probabilities': array([0.19551049, 0.80448955], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18787241], dtype=float32),
#   'logits': array([-1.4638945], dtype=float32),
#   'probabilities': array([0.8121276 , 0.18787238], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13234685], dtype=float32),
#   'logits': array([-1.8803658], dtype=float32),
#   'probabilities': array([0.8676532 , 0.13234687], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6187625], dtype=float32),
#   'logits': array([0.48429906], dtype=float32),
#   'probabilities': array([0.38123748, 0.6187625 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52430093], dtype=float32),
#   'logits': array([0.09728038], dtype=float32),
#   'probabilities': array([0.47569904, 0.52430093], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.866156], dtype=float32),
#   'logits': array([1.8673902], dtype=float32),
#   'probabilities': array([0.13384399, 0.866156  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67980397], dtype=float32),
#   'logits': array([0.7528708], dtype=float32),
#   'probabilities': array([0.32019612, 0.67980397], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13284941], dtype=float32),
#   'logits': array([-1.8759964], dtype=float32),
#   'probabilities': array([0.86715055, 0.13284941], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6808154], dtype=float32),
#   'logits': array([0.75752175], dtype=float32),
#   'probabilities': array([0.31918454, 0.6808154 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5653774], dtype=float32),
#   'logits': array([0.26301563], dtype=float32),
#   'probabilities': array([0.4346225, 0.5653774], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.79248714], dtype=float32),
#   'logits': array([1.3399827], dtype=float32),
#   'probabilities': array([0.2075129 , 0.79248714], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26975426], dtype=float32),
#   'logits': array([-0.99586976], dtype=float32),
#   'probabilities': array([0.7302457 , 0.26975423], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20426242], dtype=float32),
#   'logits': array([-1.3598639], dtype=float32),
#   'probabilities': array([0.79573756, 0.20426242], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58814687], dtype=float32),
#   'logits': array([0.3563099], dtype=float32),
#   'probabilities': array([0.41185313, 0.58814687], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17045297], dtype=float32),
#   'logits': array([-1.5824205], dtype=float32),
#   'probabilities': array([0.82954705, 0.17045297], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8137167], dtype=float32),
#   'logits': array([1.4743438], dtype=float32),
#   'probabilities': array([0.18628328, 0.8137167 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5740306], dtype=float32),
#   'logits': array([0.29831517], dtype=float32),
#   'probabilities': array([0.42596942, 0.5740306 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18979537], dtype=float32),
#   'logits': array([-1.4513403], dtype=float32),
#   'probabilities': array([0.81020457, 0.18979536], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57142174], dtype=float32),
#   'logits': array([0.28765404], dtype=float32),
#   'probabilities': array([0.42857832, 0.57142174], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52049166], dtype=float32),
#   'logits': array([0.08201265], dtype=float32),
#   'probabilities': array([0.4795083 , 0.52049166], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12821068], dtype=float32),
#   'logits': array([-1.916873], dtype=float32),
#   'probabilities': array([0.87178934, 0.12821068], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54766285], dtype=float32),
#   'logits': array([0.19123197], dtype=float32),
#   'probabilities': array([0.45233718, 0.54766285], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64872557], dtype=float32),
#   'logits': array([0.61344206], dtype=float32),
#   'probabilities': array([0.3512744 , 0.64872557], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7756701], dtype=float32),
#   'logits': array([1.2406099], dtype=float32),
#   'probabilities': array([0.22432983, 0.7756701 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82985926], dtype=float32),
#   'logits': array([1.5846298], dtype=float32),
#   'probabilities': array([0.1701408 , 0.82985926], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4888485], dtype=float32),
#   'logits': array([-0.04461336], dtype=float32),
#   'probabilities': array([0.5111515, 0.4888485], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17963108], dtype=float32),
#   'logits': array([-1.5188489], dtype=float32),
#   'probabilities': array([0.82036895, 0.17963108], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09460637], dtype=float32),
#   'logits': array([-2.258645], dtype=float32),
#   'probabilities': array([0.90539366, 0.09460637], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11526828], dtype=float32),
#   'logits': array([-2.038022], dtype=float32),
#   'probabilities': array([0.88473165, 0.11526829], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29545882], dtype=float32),
#   'logits': array([-0.86901724], dtype=float32),
#   'probabilities': array([0.70454115, 0.29545882], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36925766], dtype=float32),
#   'logits': array([-0.53540283], dtype=float32),
#   'probabilities': array([0.6307423 , 0.36925763], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29769027], dtype=float32),
#   'logits': array([-0.85832083], dtype=float32),
#   'probabilities': array([0.7023097, 0.2976903], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmp6rf2ggh_
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmp6rf2ggh_', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x10cdb32b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000) # Error

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x10ccd3dd8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh/model.ckpt.
# INFO:tensorflow:loss = 6.8316307, step = 1
# INFO:tensorflow:global_step/sec: 260.698
# INFO:tensorflow:loss = 5.463441, step = 101 (0.385 sec)
# INFO:tensorflow:global_step/sec: 413.025
# INFO:tensorflow:loss = 7.458653, step = 201 (0.242 sec)
# INFO:tensorflow:global_step/sec: 407.49
# INFO:tensorflow:loss = 3.7758915, step = 301 (0.246 sec)
# INFO:tensorflow:global_step/sec: 525.197
# INFO:tensorflow:loss = 2.7762961, step = 401 (0.189 sec)
# INFO:tensorflow:global_step/sec: 530.264
# INFO:tensorflow:loss = 4.1950293, step = 501 (0.187 sec)
# INFO:tensorflow:global_step/sec: 477.052
# INFO:tensorflow:loss = 4.076208, step = 601 (0.212 sec)
# INFO:tensorflow:global_step/sec: 383.48
# INFO:tensorflow:loss = 3.635523, step = 701 (0.259 sec)
# INFO:tensorflow:global_step/sec: 553.097
# INFO:tensorflow:loss = 5.4347577, step = 801 (0.181 sec)
# INFO:tensorflow:global_step/sec: 519.426
# INFO:tensorflow:loss = 2.754324, step = 901 (0.193 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.5376863.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-10-22:23:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-10-22:23:56
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7322835, accuracy_baseline = 0.65748036, auc = 0.8169867, auc_precision_recall = 0.67316663, average_loss = 0.5090574, global_step = 1000, label/mean = 0.34251967, loss = 4.973099, precision = 0.5940594, prediction/mean = 0.39665332, recall = 0.6896552
# {'accuracy': 0.7322835,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.8169867,
#  'auc_precision_recall': 0.67316663,
#  'average_loss': 0.5090574,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 4.973099,
#  'precision': 0.5940594,
#  'prediction/mean': 0.39665332,
#  'recall': 0.6896552}

# %%
# To export
feature_spec = tf.feature_column.make_parse_example_spec(feat_cols);
export_input_fn = tf.estimator.export.build_parsing_serving_input_receiver_fn(feature_spec);
servable_model_path = dnn_model.export_savedmodel('new_estimator_models', export_input_fn, as_text=True);
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: ['serving_default', 'classification']
# INFO:tensorflow:Signatures INCLUDED in export for Regress: ['regression']
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Restoring parameters from /var/folders/77/jl8t9nkx27q3q1536fj3b87h38zwgl/T/tmpzf1rqogh/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"new_estimator_models/temp-b'1528670387'/saved_model.pbtxt"
